# %% [markdown]
# <a href="https://colab.research.google.com/github/imsumin018/steelprice/blob/main/SteelPrice_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
df = pd.read_csv("./steel_until_2021.csv", sep='\t')
df.groupby('name')['value'].plot(legend=True, figsize=(28, 26))
# Out:
# name
# EU 열연 수입가 (CIF) (EUR/톤)                      AxesSubplot(0.125,0.125;0.775x0.755)
# LME 니켈 현물가 (U$/톤)                            AxesSubplot(0.125,0.125;0.775x0.755)
# 동남아 열연 수입가 (CFR) (U$/톤)                      AxesSubplot(0.125,0.125;0.775x0.755)
# 동남아 철근 수입가 (CFR) (U$/톤)                      AxesSubplot(0.125,0.125;0.775x0.755)
# 동아시아 철스크랩 수입가 (HMS 1/2 80:20 CFR) (U$/톤)     AxesSubplot(0.125,0.125;0.775x0.755)
# 미국 냉연 내수가 (중서부) (U$/톤)                       AxesSubplot(0.125,0.125;0.775x0.755)
# 미국 열연 내수가 (중서부) (U$/톤)                       AxesSubplot(0.125,0.125;0.775x0.755)
# 미국 철스크랩 내수가 (#1 Bushelling) (U$/Long Ton)    AxesSubplot(0.125,0.125;0.775x0.755)
# 미국 철스크랩 수출가 (HMS) (U$/톤)                     AxesSubplot(0.125,0.125;0.775x0.755)
# 미국 후판 내수가 (중서부) (U$/톤)                       AxesSubplot(0.125,0.125;0.775x0.755)
# 유럽 철스크랩 수출가 (Shredded, FOB) (U$/톤)           AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %%
# !apt -qq -y install fonts-nanum > /dev/null
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
df_by_group = df.groupby(['name'])
df_by_group = df_by_group.reset_index()
df_by_group.plot.bar(x='group',y='xval',rot=0)

# %%
pd.pivot_table(df.reset_index(),
              columns='name', values='value'
              ).plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd49a81b4d0>,
# ...
#       dtype=object)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
